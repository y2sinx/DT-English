# %% [markdown]
# 1. 将单集字幕复制到notebook
# 1. 在notebook中设置分段
# 1. 在音频或者视频中设置循环点
# 1. 扫荡所有的陌生词汇或者表达

# %% [markdown]
# Season1 Episode1
# ----------------

# %%
# %%disabled
#
# import os
# import re
# import sys
#
# def rename(workdir='F:/英语/Miranda/TXT/',pat='s[0-9]{2}e[0-9]{2}',head='Miranda_',ext='.txt',):
#     """批量重命名:newname=head+pat+ext"""
#     olddir = os.getcwd()
#     os.chdir(workdir)
#     paths = os.listdir(workdir)
#     for path in paths:
#         mid = re.findall(pat,path)
#         if mid!=[]:
#             newname = head+mid[0]+ext
#             os.rename(path, newname)
#             print(path+' -> '+newname)
#     os.chdir(olddir)
# def review():
#     """批量修改文件的内容"""
#     pass

# %% [markdown]
# Let me get you up to speed. 现在我来给你讲讲我的血泪史
# marry me off: 把我嫁出去
# blew my inheritance: 花掉我的遗产
# joke shop: 整盅玩具店
# take this franchise global: 把这个连锁推广全球
# It's a bit much. 有点过了
# Shush and submit. 闭嘴并且接受
# make a cockup: 把局面搞的一塌糊涂
# let's crack on with the show. 好戏开始了
# crack on: [口语]抓紧时间干下去
# It's nearly lunchtime. 都快午餐时间了
# a hellish journey:  地狱之旅
# That's a good one. 这回答很好
# What's up with you? 你怎么了
# It's delivery day! You aren't gonna help. 今天是送货日, 你都不来帮忙
# chocolate penises/willies: 巧克力鸡鸡/棒棒[阴茎]
# Nothing from you.  还没反应
# Can we just concentrate?  你能不能专心点
# have a reunion lunch with the girls:  跟闺蜜们小聚一下
# be dumped in a boarding school dorm 被扔进寄宿学校宿舍
# pussy: 骚包
# Work, not shirk[ʃɜːk]. 多干活少偷懒[推卸]
# Do you want our business to fold?  你想让我们的商店倒闭么
# He just called me sir.  他刚刚叫我先生
# He looked straight at me. 他直勾勾的看着我
# my girlie lunch: 我的少女午餐会
# Don't get emotional. We're not Spanish. 不要那么多愁善感 我们不是西班牙人
# news just in: 号外号外
# Call me Fiona Bruce. 叫我Fiona Bruce
# Benji has at last split up from that ghastly[ˈɡɑːstli] fish woman. Benji最终还是和那个可怕的卖鱼女分手了
# Far too fussy. 太挑剔了
# Such fun. 太搞笑了
# This isn't our delivery. 这不是我们的快递
# This is a load of baby stuff. 这是一堆宝宝用品
# sort out: 分类;清理
# Right. I'm off. 好吧, 我走了
# elegant/elephant: 优雅的/大象
# I amuse myself. 我自娱自乐
# specialist clothes shops/Big And Long: 特制服装店/肥姐高妹店
# No way. It's Gary Preston. 不会吧, 是 Gary Preston
# OK. Calm. Compose myself. 好, 淡定点, 亮个相
# trapped wind: 岔气了
# new chef: 新主厨
# Be sensible: 要懂事了
# gymnastics/gymnast/ribbons: 体操/体操运动员/彩带
# I'd better get back to work. 我要回去工作了
# Oh, hang on. Bear with. Bear with. -Back [正在打电话的人对想打断电话的人说]等一下,忍一下,忍一下
# Marriage and the baby thing, honestly, it's not for me. 结婚生子, 不是我想要的
# shopping bonanza: 购物大血拼
# I didn't quite catch it. 我没听清楚
# I'm going insane. 我快疯了
# So, I'm a cock magnet. Shoot me. 我就是个吸阳圣女. 射死我吧
# Do you fancy grabbing a bite later?  你愿不愿意过后一起吃点东西
# I'll pop in when I've finished my shift. 我下班就来找你
# Where are you going?  你要去哪
# scare sb off: 把某人吓跑
# fluffy handcuffs: 毛绒绕的手铐[SM手铐]
# That was your fault, get out. 都怪你, 快滚
